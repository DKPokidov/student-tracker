# %%
from utils import read_students_from_file
import tracker

PATH = 'data/students_list.txt'
students = read_students_from_file(PATH)
py = tracker.Course(name ='Python for beginners', 
                students=students)

# %%
py.get_all_students()
# Out:
# 1. Александрова Д. М.
# 2. Бокова П. И.
# 3. Зайкова В. Д.
# 4. Казакова А. Н.
# 5. Медведева А. С.
# 6. Павлов И. О.
# 7. Пащенко Е. К.
# 8. Пеньков Г. М.
# 9. Поляков Д. Э.
# 10. Сазонова А. А.
# 11. Шадрин Е. М.

# %%
py.add_student('Пупкин П. П.')
py.get_all_students()
# Out:
# 1. Александрова Д. М.
# 2. Бокова П. И.
# 3. Зайкова В. Д.
# 4. Казакова А. Н.
# 5. Медведева А. С.
# 6. Павлов И. О.
# 7. Пащенко Е. К.
# 8. Пеньков Г. М.
# 9. Поляков Д. Э.
# 10. Пупкин П. П.
# 11. Сазонова А. А.
# 12. Шадрин Е. М.

# %%
py.remove_student('Пупкин П. П.')
py.get_all_students()
# Out:
# 1. Александрова Д. М.
# 2. Бокова П. И.
# 3. Зайкова В. Д.
# 4. Казакова А. Н.
# 5. Медведева А. С.
# 6. Павлов И. О.
# 7. Пащенко Е. К.
# 8. Пеньков Г. М.
# 9. Поляков Д. Э.
# 10. Сазонова А. А.
# 11. Шадрин Е. М.

# %%
py.add_topic(
    name='Analyzis',
    type = 'LecTure',
    max_score=15
)
# Out:
# Topic 'Analyzis' added.

# %%
py.get_all_topics()
# Out:
# [{'topic_name': 'Analyzis', 'topic_type': 'lecture', 'topic_max_score': 15}]

# %%
py.save_to_file('D:/Work/ITMO/student_tracker/data/topics_list.json')

# %%
py.add_topic(
    name='Pandas',
    type = 'practice',
    max_score=20
)
# Out:
# Topic 'Pandas' added.

# %%
py.get_all_topics()
# Out:
# [{'topic_name': 'Analyzis', 'topic_type': 'lecture', 'topic_max_score': 15},
#  {'topic_name': 'Pandas', 'topic_type': 'practice', 'topic_max_score': 20}]

# %%
py.students
# Out:
# ['Александрова Д. М.',
#  'Бокова П. И.',
#  'Зайкова В. Д.',
#  'Казакова А. Н.',
#  'Медведева А. С.',
#  'Павлов И. О.',
#  'Пащенко Е. К.',
#  'Пеньков Г. М.',
#  'Поляков Д. Э.',
#  'Сазонова А. А.',
#  'Шадрин Е. М.']

# %%
py.load_from_file('D:/Work/ITMO/student_tracker/data/topics_list.json')
# Out:
# Data successfully loaded from the file.

# %%
py.topics
# Out:
# [{'topic_name': 'Analyzis', 'topic_type': 'lecture', 'topic_max_score': 15}]

# %%
py.students
# Out:
# ['Александрова Д. М.',
#  'Бокова П. И.',
#  'Зайкова В. Д.',
#  'Казакова А. Н.',
#  'Медведева А. С.',
#  'Павлов И. О.',
#  'Пащенко Е. К.',
#  'Пеньков Г. М.',
#  'Поляков Д. Э.',
#  'Сазонова А. А.',
#  'Шадрин Е. М.']

# %%
py.set_grade("Александрова Д. М.", "Analyzis", 15)
# Out:
# Attributes Александрова Д. М., Analyzis and 15 have successfully added to course!

# %%
py.grades
# Out:
# {}
