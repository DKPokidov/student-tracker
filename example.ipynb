# %%
from utils import read_students_from_file
import tracker

PATH = 'data/students_list.txt'
students = read_students_from_file(PATH)
py = tracker.Course(name ='Python for beginners', 
                students=students)

# %%
py.get_all_students()
# Out:
# 1.
# 2. Александрова Д. М.
# 3. Бокова П. И.
# 4. Зайкова В. Д.
# 5. Казакова А. Н.
# 6. Медведева А. С.
# 7. Павлов И. О.
# 8. Пащенко Е. К.
# 9. Пеньков Г. М.
# 10. Поляков Д. Э.
# 11. Сазонова А. А.
# 12. Шадрин Е. М.

# %%
py.add_student('Пупкин П. П.')
py.get_all_students()
# Out:
# 1.
# 2. Александрова Д. М.
# 3. Бокова П. И.
# 4. Зайкова В. Д.
# 5. Казакова А. Н.
# 6. Медведева А. С.
# 7. Павлов И. О.
# 8. Пащенко Е. К.
# 9. Пеньков Г. М.
# 10. Поляков Д. Э.
# 11. Пупкин П. П.
# 12. Сазонова А. А.
# 13. Шадрин Е. М.

# %%
py.remove_student('Пупкин П. П.')
py.get_all_students()
# Out:
# 1.
# 2. Александрова Д. М.
# 3. Бокова П. И.
# 4. Зайкова В. Д.
# 5. Казакова А. Н.
# 6. Медведева А. С.
# 7. Павлов И. О.
# 8. Пащенко Е. К.
# 9. Пеньков Г. М.
# 10. Поляков Д. Э.
# 11. Сазонова А. А.
# 12. Шадрин Е. М.

# %%
py.add_topic(
    name='OOP',
    type = 'practice',
    max_score=15
)

# %%
py.get_all_topics()
# Out:
# [{'topic_name': 'Begining of Python',
#   'topic_type': 'lecture',
#   'topic_max_score': 20},
#  {'topic_name': 'OOP', 'topic_type': 'practice', 'topic_max_score': 15}]

# %%
py.save_to_file('D:/Work/ITMO/student_tracker/data/topics_list.json')

# %%
py.add_topic(
    name='Pandas',
    type = 'practice',
    max_score=20
)

# %%
py.get_all_topics()
# Out:
# [{'topic_name': 'Begining of Python',
#   'topic_type': 'lecture',
#   'topic_max_score': 20},
#  {'topic_name': 'OOP', 'topic_type': 'practice', 'topic_max_score': 15},
#  {'topic_name': 'Pandas', 'topic_type': 'practice', 'topic_max_score': 20}]

# %%
py.load_from_file('D:/Work/ITMO/student_tracker/data/topics_list.json')
# Out:
# Unexpected error: AttributeError: 'list' object has no attribute 'get'
